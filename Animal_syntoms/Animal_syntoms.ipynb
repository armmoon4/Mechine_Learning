# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"/content/drive/MyDrive/Colab Notebooks/Syntoms_of_Animal/3. data - 3. data.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#   AnimalName symptoms1             symptoms2 symptoms3    symptoms4  \
# 0        Dog     Fever              Diarrhea  Vomiting  Weight loss
# 1        Dog     Fever              Diarrhea  Coughing    Tiredness
# 2        Dog     Fever              Diarrhea  Coughing     Vomiting
# 3        Dog     Fever  Difficulty breathing  Coughing     Lethargy
# 4        Dog     Fever              Diarrhea  Coughing     Lethargy
#
#      symptoms5 Dangerous
# 0  Dehydration       Yes
# 1        Pains       Yes
# 2     Anorexia       Yes
# 3     Sneezing       Yes
# 4     Blue Eye       Yes

# %%
df
# Out:
#     AnimalName                        symptoms1             symptoms2  \
# 0          Dog                            Fever              Diarrhea
# 1          Dog                            Fever              Diarrhea
# 2          Dog                            Fever              Diarrhea
# 3          Dog                            Fever  Difficulty breathing
# 4          Dog                            Fever              Diarrhea
# ..         ...                              ...                   ...
# 866  Buffaloes                            Fever  Difficulty breathing
# 867  Buffaloes                            Fever     Loss of  appetite
# 868  Buffaloes      Lesions in the nasal cavity       Lesions on nose
# 869  Buffaloes                        Hair loss              Dandruff
# 870  Buffaloes  Greenish-yellow nasal discharge  Lack of pigmentation
#
#                symptoms3             symptoms4           symptoms5 Dangerous
# 0               Vomiting           Weight loss         Dehydration       Yes
# 1               Coughing             Tiredness               Pains       Yes
# 2               Coughing              Vomiting            Anorexia       Yes
# 3               Coughing              Lethargy            Sneezing       Yes
# 4               Coughing              Lethargy            Blue Eye       Yes
# ..                   ...                   ...                 ...       ...
# 866        Poor Appetite   Eye and Skin change  Unable to exercise       Yes
# 867  Lession on the skin              Lethargy          Joint Pain       Yes
# 868             Vomiting       Noisy Breathing     Lesions on nose       Yes
# 869             Vomiting  Crusting of the skin      Ulcerated skin       Yes
# 870             Vomiting              Lethargy        Pain on face       Yes
#
# [871 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 871 entries, 0 to 870
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   AnimalName  871 non-null    object
#  1   symptoms1   871 non-null    object
#  2   symptoms2   871 non-null    object
#  3   symptoms3   871 non-null    object
#  4   symptoms4   871 non-null    object
#  5   symptoms5   871 non-null    object
#  6   Dangerous   869 non-null    object
# dtypes: object(7)
# memory usage: 47.8+ KB

# %%
df.describe()
# Out:
#        AnimalName symptoms1 symptoms2 symptoms3    symptoms4 symptoms5  \
# count         871       871       871       871          871       871
# unique         45       232       230       228          217       203
# top     Buffaloes     Fever  Diarrhea  Coughing  Weight loss     Pains
# freq          129       257       119        95          117        99
#
#        Dangerous
# count        869
# unique         2
# top          Yes
# freq         849

# %%
x = df.iloc[:,: -1].values
y = df.iloc[:, 6 :].values
print(x)
print(y)
# Out:
# [['Dog' 'Fever' 'Diarrhea' 'Vomiting' 'Weight loss' 'Dehydration']
#  ['Dog' 'Fever' 'Diarrhea' 'Coughing' 'Tiredness' 'Pains']
#  ['Dog' 'Fever' 'Diarrhea' 'Coughing' 'Vomiting' 'Anorexia']
#  ...
#  ['Buffaloes' 'Lesions in the nasal cavity' 'Lesions on nose' 'Vomiting'
#   'Noisy Breathing' 'Lesions on nose']
#  ['Buffaloes' 'Hair loss' 'Dandruff' 'Vomiting' 'Crusting of the skin'
#   'Ulcerated skin']
#  ['Buffaloes' 'Greenish-yellow nasal discharge' 'Lack of pigmentation'
#   'Vomiting' 'Lethargy' 'Pain on face']]
# [['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  [nan]
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['No']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  [nan]
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']
#  ['Yes']]

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
x[:,0]=LE.fit_transform(x[:,0])
x
# Out:
# array([[31, 'Fever', 'Diarrhea', 'Vomiting', 'Weight loss',
#         'Dehydration'],
#        [112, 'Fever', 'Diarrhea', 'Coughing', 'Tiredness', 'Pains'],
#        [7, 'Fever', 'Diarrhea', 'Coughing', 'Vomiting', 'Anorexia'],
#        ...,
#        [81, 'Lesions in the nasal cavity', 'Lesions on nose', 'Vomiting',
#         'Noisy Breathing', 'Lesions on nose'],
#        [158, 'Hair loss', 'Dandruff', 'Vomiting', 'Crusting of the skin',
#         'Ulcerated skin'],
#        [110, 'Greenish-yellow nasal discharge', 'Lack of pigmentation',
#         'Vomiting', 'Lethargy', 'Pain on face']], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
x[:,1]=LE.fit_transform(x[:,1])
x
# Out:
# array([[31, 62, 'Diarrhea', 'Vomiting', 'Weight loss', 'Dehydration'],
#        [112, 62, 'Diarrhea', 'Coughing', 'Tiredness', 'Pains'],
#        [7, 62, 'Diarrhea', 'Coughing', 'Vomiting', 'Anorexia'],
#        ...,
#        [81, 96, 'Lesions on nose', 'Vomiting', 'Noisy Breathing',
#         'Lesions on nose'],
#        [158, 76, 'Dandruff', 'Vomiting', 'Crusting of the skin',
#         'Ulcerated skin'],
#        [110, 74, 'Lack of pigmentation', 'Vomiting', 'Lethargy',
#         'Pain on face']], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
x[:,2]=LE.fit_transform(x[:,2])
x
# Out:
# array([[31, 62, 31, 'Vomiting', 'Weight loss', 'Dehydration'],
#        [112, 62, 31, 'Coughing', 'Tiredness', 'Pains'],
#        [7, 62, 31, 'Coughing', 'Vomiting', 'Anorexia'],
#        ...,
#        [81, 96, 90, 'Vomiting', 'Noisy Breathing', 'Lesions on nose'],
#        [158, 76, 26, 'Vomiting', 'Crusting of the skin',
#         'Ulcerated skin'],
#        [110, 74, 84, 'Vomiting', 'Lethargy', 'Pain on face']],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
x[:,3]=LE.fit_transform(x[:,3])
x
# Out:
# array([[31, 62, 31, 178, 'Weight loss', 'Dehydration'],
#        [112, 62, 31, 31, 'Tiredness', 'Pains'],
#        [7, 62, 31, 31, 'Vomiting', 'Anorexia'],
#        ...,
#        [81, 96, 90, 178, 'Noisy Breathing', 'Lesions on nose'],
#        [158, 76, 26, 178, 'Crusting of the skin', 'Ulcerated skin'],
#        [110, 74, 84, 178, 'Lethargy', 'Pain on face']], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
x[:,4]=LE.fit_transform(x[:,4])
x
# Out:
# array([[31, 62, 31, 178, 182, 'Dehydration'],
#        [112, 62, 31, 31, 165, 'Pains'],
#        [7, 62, 31, 31, 173, 'Anorexia'],
#        ...,
#        [81, 96, 90, 178, 107, 'Lesions on nose'],
#        [158, 76, 26, 178, 27, 'Ulcerated skin'],
#        [110, 74, 84, 178, 87, 'Pain on face']], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
x[:,5]=LE.fit_transform(x[:,5])
x
# Out:
# array([[31, 62, 31, 178, 182, 31],
#        [112, 62, 31, 31, 165, 112],
#        [7, 62, 31, 31, 173, 7],
#        ...,
#        [81, 96, 90, 178, 107, 81],
#        [158, 76, 26, 178, 27, 158],
#        [110, 74, 84, 178, 87, 110]], dtype=object)

# %%
from sklearn.metrics import accuracy_score
y_encoded = LE.fit_transform(y.ravel())
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
y_pred_binary = np.round(y_pred).astype(int)
accuracy = accuracy_score(y_test, y_pred_binary)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.9942857142857143

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)
mse_train = mean_squared_error(y_train, y_train_pred)
r2_train = r2_score(y_train, y_train_pred)

mse_test = mean_squared_error(y_test, y_test_pred)
r2_test = r2_score(y_test, y_test_pred)

print(f'Training Mean Squared Error: {mse_train}')
print(f'Training R-squared: {r2_train}')
print(f'Test Mean Squared Error: {mse_test}')
print(f'Test R-squared: {r2_test}')
# Out:
# Training Mean Squared Error: 0.016105788407376052
# Training R-squared: 0.42901774025560047
# Test Mean Squared Error: 0.006344639818508982
# Test R-squared: 0.4384260276247469

# %%
import matplotlib.pyplot as plt

# Calculate residuals (difference between actual and predicted values)
residuals = y_test - y_pred

# Plot residuals
plt.scatter(y_test, residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %%
from sklearn.metrics import classification_report


y_pred_binary = np.round(y_pred).astype(int)

report = classification_report(y_test, y_pred_binary)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.99      1.00      1.00       173
#
#     accuracy                           0.99       175
#    macro avg       1.00      0.75      0.83       175
# weighted avg       0.99      0.99      0.99       175

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
import numpy as np


y_encoded = LE.fit_transform(y.ravel())
model = LinearRegression()


cv_scores = cross_val_score(model, x, y_encoded, cv=5, scoring='neg_mean_squared_error')
rmse_scores = np.sqrt(-cv_scores)

# Display the cross-validation scores
print("Cross-Validation RMSE Scores:", rmse_scores)
print("Mean RMSE:", np.mean(rmse_scores))
# Out:
# Cross-Validation RMSE Scores: [0.0578727  0.1860729  0.03458079 0.18593892 0.04839449]
# Mean RMSE: 0.10257195983429301

# %% [markdown]
# Decision TREEE

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
y_encoded = LE.fit_transform(y.ravel())
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=0)

# %%
dt_classifier = DecisionTreeClassifier(random_state=0)
dt_classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred = dt_classifier.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 1.0
# Confusion Matrix:
# [[  2   0]
#  [  0 173]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00       173
#
#     accuracy                           1.00       175
#    macro avg       1.00      1.00      1.00       175
# weighted avg       1.00      1.00      1.00       175

# %% [markdown]
# Random FOREST

# %%
from sklearn.ensemble import RandomForestClassifier


y_encoded = LE.fit_transform(y.ravel())
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=0)
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=0)  # You can adjust the number of estimators as needed
rf_classifier.fit(x_train, y_train)
y_pred = rf_classifier.predict(x_test)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Display the results
print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 1.0
# Confusion Matrix:
# [[  2   0]
#  [  0 173]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00       173
#
#     accuracy                           1.00       175
#    macro avg       1.00      1.00      1.00       175
# weighted avg       1.00      1.00      1.00       175
